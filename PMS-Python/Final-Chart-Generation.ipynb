# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

norms_fake_na_lst = []
norms_fake_lst = []
norms_pms_lst = []

ganv_lst = []
bot_lst = []
ks_lst = []
lr_lst = []
is_lst = []

for gan_version in ['15ConstSpac', '34Orig', '34HighDensity', '34Expanded15']:
    for bot in range(96,107):
        for kernel_size in [1, 2, 3]:
            for lr_val in [0.001, 0.0001]:
                for infer_stud in [True, False]:
                    try:
                        norms_fake = np.load(f'./bottle_info/{gan_version}_{bot}_{kernel_size}_{lr_val}_{infer_stud}_norms_fake_.npy')
                        actual_pts_keep_fake = np.load(f'./bottle_info/{gan_version}_{bot}_{kernel_size}_{lr_val}_{infer_stud}_actual_pts_keep_fake_.npy')
                        scl_iv_keep_fake = np.load(f'./bottle_info/{gan_version}_{bot}_{kernel_size}_{lr_val}_{infer_stud}_scl_iv_keep_fake_.npy')
                        norms_pms = np.load(f'./bottle_info/{gan_version}_{bot}_{kernel_size}_{lr_val}_{infer_stud}_norms_pms_.npy')
                        actual_pts_keep_pms = np.load(f'./bottle_info/{gan_version}_{bot}_{kernel_size}_{lr_val}_{infer_stud}_actual_pts_keep_pms_.npy')
                        scl_iv_keep_pms = np.load(f'./bottle_info/{gan_version}_{bot}_{kernel_size}_{lr_val}_{infer_stud}_scl_iv_keep_pms_.npy')
                        plot_setup = np.load(f'./bottle_info/{gan_version}_{bot}_{kernel_size}_{lr_val}_{infer_stud}_plot_setup_.npy')
                        
                        ganv_lst.append(gan_version)
                        bot_lst.append(bot)
                        ks_lst.append(kernel_size)
                        lr_lst.append(lr_val)
                        is_lst.append(infer_stud)
                        norms_fake_lst.append(norms_fake.mean())
                        norms_pms_lst.append(norms_pms.mean())
                    except:
                        print(f'Missing Combo: GAN—{gan_version}, Bottle—{bot}, Kernel Size—{kernel_size}, Learning Rate—{lr_val}, Inferred Studio—{infer_stud}')
                        continue
# Out:
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—1, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—1, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—2, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—2, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—3, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—3, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—98, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—1, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—1, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—2, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—2, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—3, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—3, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—15ConstSpac, Bottle—106, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—1, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—1, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—2, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—2, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—3, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—3, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—98, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—1, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—1, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—2, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—2, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—3, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—3, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Orig, Bottle—106, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—1, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—1, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—2, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—2, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—3, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—3, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—98, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—1, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—1, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—2, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—2, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—3, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—3, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34HighDensity, Bottle—106, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—1, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—1, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—2, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—2, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—3, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—3, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—98, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—1, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—1, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—1, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—2, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—2, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—2, Learning Rate—0.0001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—3, Learning Rate—0.001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—3, Learning Rate—0.001, Inferred Studio—False
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—True
# Missing Combo: GAN—34Expanded15, Bottle—106, Kernel Size—3, Learning Rate—0.0001, Inferred Studio—False

# %%
len(bot_lst)
# Out:
# 432

# %%
norms = pd.DataFrame([ganv_lst,
                      bot_lst,
                      ks_lst,
                      lr_lst,
                      is_lst,
                      norms_fake_lst,
                      norms_pms_lst], index=['gan_version',
                                             'bot_num',
                                             'kernel',
                                             'learning_rate',
                                             'inferred_stud',
                                             'norms_fake_lst',
                                             'norms_pms_lst']).T

with pd.option_context('max_rows',1000):
    display(norms)

norms.to_csv('tmp_norm_csv_output-final.csv')
# Out:
#        gan_version bot_num kernel learning_rate inferred_stud norms_fake_lst  \
# 0      15ConstSpac      96      1         0.001          True       0.132538
# 1      15ConstSpac      96      1         0.001         False       0.128172
# 2      15ConstSpac      96      1        0.0001          True       0.192778
# 3      15ConstSpac      96      1        0.0001         False       0.188855
# 4      15ConstSpac      96      2         0.001          True       0.127754
# 5      15ConstSpac      96      2         0.001         False       0.136348
# 6      15ConstSpac      96      2        0.0001          True       0.194176
# 7      15ConstSpac      96      2        0.0001         False       0.190539
# 8      15ConstSpac      96      3         0.001          True       0.140808
# 9      15ConstSpac      96      3         0.001         False        0.14299
# 10     15ConstSpac      96      3        0.0001          True         0.1815
# 11     15ConstSpac      96      3        0.0001         False       0.178094
# 12     15ConstSpac      97      1         0.001          True       0.347536
# 13     15ConstSpac      97      1         0.001         False       0.345868
# 14     15ConstSpac      97      1        0.0001          True        0.48279
# 15     15ConstSpac      97      1        0.0001         False       0.399296
# 16     15ConstSpac      97      2         0.001          True       0.347456
# 17     15ConstSpac      97      2         0.001         False        0.34029
# 18     15ConstSpac      97      2        0.0001          True       0.513535
# 19     15ConstSpac      97      2        0.0001         False       0.448483
# 20     15ConstSpac      97      3         0.001          True       0.339379
# 21     15ConstSpac      97      3         0.001         False       0.341123
# 22     15ConstSpac      97      3        0.0001          True       0.538528
# 23     15ConstSpac      97      3        0.0001         False       0.473011
# 24     15ConstSpac      99      1         0.001          True       0.151131
# 25     15ConstSpac      99      1         0.001         False       0.197779
# 26     15ConstSpac      99      1        0.0001          True       0.353085
# 27     15ConstSpac      99      1        0.0001         False       0.375946
# 28     15ConstSpac      99      2         0.001          True      0.0994458
# 29     15ConstSpac      99      2         0.001         False      0.0870645
# 30     15ConstSpac      99      2        0.0001          True       0.336562
# 31     15ConstSpac      99      2        0.0001         False       0.357901
# 32     15ConstSpac      99      3         0.001          True       0.080117
# 33     15ConstSpac      99      3         0.001         False      0.0717274
# 34     15ConstSpac      99      3        0.0001          True       0.348895
# 35     15ConstSpac      99      3        0.0001         False       0.375931
# 36     15ConstSpac     100      1         0.001          True        0.18392
# 37     15ConstSpac     100      1         0.001         False       0.189246
# 38     15ConstSpac     100      1        0.0001          True       0.218231
# 39     15ConstSpac     100      1        0.0001         False       0.169636
# 40     15ConstSpac     100      2         0.001          True       0.172981
# 41     15ConstSpac     100      2         0.001         False        0.17988
# 42     15ConstSpac     100      2        0.0001          True       0.182164
# 43     15ConstSpac     100      2        0.0001         False       0.152859
# 44     15ConstSpac     100      3         0.001          True       0.168149
# 45     15ConstSpac     100      3         0.001         False       0.170099
# 46     15ConstSpac     100      3        0.0001          True       0.175662
# 47     15ConstSpac     100      3        0.0001         False       0.141187
# 48     15ConstSpac     101      1         0.001          True       0.251132
# 49     15ConstSpac     101      1         0.001         False       0.252216
# 50     15ConstSpac     101      1        0.0001          True       0.242002
# 51     15ConstSpac     101      1        0.0001         False       0.246285
# 52     15ConstSpac     101      2         0.001          True       0.245885
# 53     15ConstSpac     101      2         0.001         False        0.22482
# 54     15ConstSpac     101      2        0.0001          True       0.134036
# 55     15ConstSpac     101      2        0.0001         False       0.544944
# 56     15ConstSpac     101      3         0.001          True       0.233094
# 57     15ConstSpac     101      3         0.001         False       0.220436
# 58     15ConstSpac     101      3        0.0001          True      0.0543079
# 59     15ConstSpac     101      3        0.0001         False      0.0694951
# 60     15ConstSpac     102      1         0.001          True            inf
# 61     15ConstSpac     102      1         0.001         False            inf
# 62     15ConstSpac     102      1        0.0001          True            inf
# 63     15ConstSpac     102      1        0.0001         False            inf
# 64     15ConstSpac     102      2         0.001          True            inf
# 65     15ConstSpac     102      2         0.001         False            inf
# 66     15ConstSpac     102      2        0.0001          True            inf
# 67     15ConstSpac     102      2        0.0001         False            inf
# 68     15ConstSpac     102      3         0.001          True            inf
# 69     15ConstSpac     102      3         0.001         False            inf
# 70     15ConstSpac     102      3        0.0001          True            inf
# 71     15ConstSpac     102      3        0.0001         False            inf
# 72     15ConstSpac     103      1         0.001          True      0.0787626
# 73     15ConstSpac     103      1         0.001         False      0.0583782
# 74     15ConstSpac     103      1        0.0001          True        0.24452
# 75     15ConstSpac     103      1        0.0001         False       0.262887
# 76     15ConstSpac     103      2         0.001          True      0.0701374
# 77     15ConstSpac     103      2         0.001         False       0.141253
# 78     15ConstSpac     103      2        0.0001          True       0.216949
# 79     15ConstSpac     103      2        0.0001         False       0.291425
# 80     15ConstSpac     103      3         0.001          True       0.049866
# 81     15ConstSpac     103      3         0.001         False       0.158228
# 82     15ConstSpac     103      3        0.0001          True       0.185618
# 83     15ConstSpac     103      3        0.0001         False       0.219974
# 84     15ConstSpac     104      1         0.001          True            inf
# 85     15ConstSpac     104      1         0.001         False            inf
# 86     15ConstSpac     104      1        0.0001          True       0.354789
# 87     15ConstSpac     104      1        0.0001         False       0.382818
# 88     15ConstSpac     104      2         0.001          True            inf
# 89     15ConstSpac     104      2         0.001         False            inf
# 90     15ConstSpac     104      2        0.0001          True       0.212517
# 91     15ConstSpac     104      2        0.0001         False       0.287096
# 92     15ConstSpac     104      3         0.001          True            inf
# 93     15ConstSpac     104      3         0.001         False            inf
# 94     15ConstSpac     104      3        0.0001          True       0.118646
# 95     15ConstSpac     104      3        0.0001         False       0.178913
# 96     15ConstSpac     105      1         0.001          True       0.133926
# 97     15ConstSpac     105      1         0.001         False       0.157885
# 98     15ConstSpac     105      1        0.0001          True       0.414186
# 99     15ConstSpac     105      1        0.0001         False       0.245181
# 100    15ConstSpac     105      2         0.001          True      0.0772601
# 101    15ConstSpac     105      2         0.001         False       0.103741
# 102    15ConstSpac     105      2        0.0001          True       0.272396
# 103    15ConstSpac     105      2        0.0001         False       0.354559
# 104    15ConstSpac     105      3         0.001          True      0.0612298
# 105    15ConstSpac     105      3         0.001         False      0.0775849
# 106    15ConstSpac     105      3        0.0001          True       0.269269
# 107    15ConstSpac     105      3        0.0001         False       0.342805
# 108         34Orig      96      1         0.001          True       0.179123
# 109         34Orig      96      1         0.001         False       0.210998
# 110         34Orig      96      1        0.0001          True            inf
# 111         34Orig      96      1        0.0001         False            inf
# 112         34Orig      96      2         0.001          True       0.167482
# 113         34Orig      96      2         0.001         False       0.202969
# 114         34Orig      96      2        0.0001          True            inf
# 115         34Orig      96      2        0.0001         False            inf
# 116         34Orig      96      3         0.001          True       0.171978
# 117         34Orig      96      3         0.001         False       0.180504
# 118         34Orig      96      3        0.0001          True            inf
# 119         34Orig      96      3        0.0001         False            inf
# 120         34Orig      97      1         0.001          True       0.200086
# 121         34Orig      97      1         0.001         False       0.248757
# 122         34Orig      97      1        0.0001          True            inf
# 123         34Orig      97      1        0.0001         False            inf
# 124         34Orig      97      2         0.001          True       0.283936
# 125         34Orig      97      2         0.001         False       0.221647
# 126         34Orig      97      2        0.0001          True            inf
# 127         34Orig      97      2        0.0001         False            inf
# 128         34Orig      97      3         0.001          True        0.19989
# 129         34Orig      97      3         0.001         False        0.20282
# 130         34Orig      97      3        0.0001          True            inf
# 131         34Orig      97      3        0.0001         False            inf
# 132         34Orig      99      1         0.001          True       0.291585
# 133         34Orig      99      1         0.001         False       0.211002
# 134         34Orig      99      1        0.0001          True            inf
# 135         34Orig      99      1        0.0001         False            inf
# 136         34Orig      99      2         0.001          True       0.245329
# 137         34Orig      99      2         0.001         False      0.0837736
# 138         34Orig      99      2        0.0001          True            inf
# 139         34Orig      99      2        0.0001         False            inf
# 140         34Orig      99      3         0.001          True       0.156948
# 141         34Orig      99      3         0.001         False       0.154421
# 142         34Orig      99      3        0.0001          True            inf
# 143         34Orig      99      3        0.0001         False            inf
# 144         34Orig     100      1         0.001          True       0.207548
# 145         34Orig     100      1         0.001         False       0.207988
# 146         34Orig     100      1        0.0001          True            inf
# 147         34Orig     100      1        0.0001         False            inf
# 148         34Orig     100      2         0.001          True       0.201313
# 149         34Orig     100      2         0.001         False       0.104435
# 150         34Orig     100      2        0.0001          True            inf
# 151         34Orig     100      2        0.0001         False            inf
# 152         34Orig     100      3         0.001          True       0.217495
# 153         34Orig     100      3         0.001         False       0.250609
# 154         34Orig     100      3        0.0001          True            inf
# 155         34Orig     100      3        0.0001         False            inf
# 156         34Orig     101      1         0.001          True       0.119893
# 157         34Orig     101      1         0.001         False       0.128606
# 158         34Orig     101      1        0.0001          True            inf
# 159         34Orig     101      1        0.0001         False            inf
# 160         34Orig     101      2         0.001          True       0.230477
# 161         34Orig     101      2         0.001         False       0.231567
# 162         34Orig     101      2        0.0001          True            inf
# 163         34Orig     101      2        0.0001         False            inf
# 164         34Orig     101      3         0.001          True       0.287988
# 165         34Orig     101      3         0.001         False       0.258297
# 166         34Orig     101      3        0.0001          True            inf
# 167         34Orig     101      3        0.0001         False            inf
# 168         34Orig     102      1         0.001          True        0.42527
# 169         34Orig     102      1         0.001         False       0.067998
# 170         34Orig     102      1        0.0001          True            inf
# 171         34Orig     102      1        0.0001         False            inf
# 172         34Orig     102      2         0.001          True       0.412837
# 173         34Orig     102      2         0.001         False      0.0800693
# 174         34Orig     102      2        0.0001          True            inf
# 175         34Orig     102      2        0.0001         False            inf
# 176         34Orig     102      3         0.001          True       0.416119
# 177         34Orig     102      3         0.001         False      0.0568647
# 178         34Orig     102      3        0.0001          True            inf
# 179         34Orig     102      3        0.0001         False            inf
# 180         34Orig     103      1         0.001          True       0.154428
# 181         34Orig     103      1         0.001         False       0.132622
# 182         34Orig     103      1        0.0001          True            inf
# 183         34Orig     103      1        0.0001         False            inf
# 184         34Orig     103      2         0.001          True       0.124902
# 185         34Orig     103      2         0.001         False       0.101055
# 186         34Orig     103      2        0.0001          True            inf
# 187         34Orig     103      2        0.0001         False            inf
# 188         34Orig     103      3         0.001          True       0.168549
# 189         34Orig     103      3         0.001         False       0.151763
# 190         34Orig     103      3        0.0001          True            inf
# 191         34Orig     103      3        0.0001         False            inf
# 192         34Orig     104      1         0.001          True      0.0904422
# 193         34Orig     104      1         0.001         False      0.0896273
# 194         34Orig     104      1        0.0001          True            inf
# 195         34Orig     104      1        0.0001         False            inf
# 196         34Orig     104      2         0.001          True      0.0991066
# 197         34Orig     104      2         0.001         False       0.112237
# 198         34Orig     104      2        0.0001          True            inf
# 199         34Orig     104      2        0.0001         False            inf
# 200         34Orig     104      3         0.001          True       0.138951
# 201         34Orig     104      3         0.001         False       0.153217
# 202         34Orig     104      3        0.0001          True            inf
# 203         34Orig     104      3        0.0001         False            inf
# 204         34Orig     105      1         0.001          True       0.158948
# 205         34Orig     105      1         0.001         False       0.132278
# 206         34Orig     105      1        0.0001          True            inf
# 207         34Orig     105      1        0.0001         False            inf
# 208         34Orig     105      2         0.001          True       0.115619
# 209         34Orig     105      2         0.001         False      0.0946978
# 210         34Orig     105      2        0.0001          True            inf
# 211         34Orig     105      2        0.0001         False            inf
# 212         34Orig     105      3         0.001          True      0.0782957
# 213         34Orig     105      3         0.001         False      0.0790855
# 214         34Orig     105      3        0.0001          True            inf
# 215         34Orig     105      3        0.0001         False            inf
# 216  34HighDensity      96      1         0.001          True       0.194591
# 217  34HighDensity      96      1         0.001         False       0.232593
# 218  34HighDensity      96      1        0.0001          True       0.213098
# 219  34HighDensity      96      1        0.0001         False       0.268339
# 220  34HighDensity      96      2         0.001          True       0.194316
# 221  34HighDensity      96      2         0.001         False       0.194962
# 222  34HighDensity      96      2        0.0001          True       0.216343
# 223  34HighDensity      96      2        0.0001         False       0.233095
# 224  34HighDensity      96      3         0.001          True       0.196392
# 225  34HighDensity      96      3         0.001         False       0.197611
# 226  34HighDensity      96      3        0.0001          True       0.243543
# 227  34HighDensity      96      3        0.0001         False       0.235779
# 228  34HighDensity      97      1         0.001          True       0.424721
# 229  34HighDensity      97      1         0.001         False       0.390914
# 230  34HighDensity      97      1        0.0001          True            inf
# 231  34HighDensity      97      1        0.0001         False       0.161911
# 232  34HighDensity      97      2         0.001          True       0.446498
# 233  34HighDensity      97      2         0.001         False       0.410763
# 234  34HighDensity      97      2        0.0001          True            inf
# 235  34HighDensity      97      2        0.0001         False         0.1363
# 236  34HighDensity      97      3         0.001          True       0.460522
# 237  34HighDensity      97      3         0.001         False       0.437449
# 238  34HighDensity      97      3        0.0001          True            inf
# 239  34HighDensity      97      3        0.0001         False       0.148973
# 240  34HighDensity      99      1         0.001          True        0.40761
# 241  34HighDensity      99      1         0.001         False       0.188863
# 242  34HighDensity      99      1        0.0001          True        0.14163
# 243  34HighDensity      99      1        0.0001         False       0.186381
# 244  34HighDensity      99      2         0.001          True       0.327754
# 245  34HighDensity      99      2         0.001         False       0.202694
# 246  34HighDensity      99      2        0.0001          True        0.11242
# 247  34HighDensity      99      2        0.0001         False       0.171972
# 248  34HighDensity      99      3         0.001          True        0.11416
# 249  34HighDensity      99      3         0.001         False       0.273534
# 250  34HighDensity      99      3        0.0001          True      0.0850983
# 251  34HighDensity      99      3        0.0001         False       0.115336
# 252  34HighDensity     100      1         0.001          True       0.162512
# 253  34HighDensity     100      1         0.001         False       0.130977
# 254  34HighDensity     100      1        0.0001          True       0.181029
# 255  34HighDensity     100      1        0.0001         False       0.154846
# 256  34HighDensity     100      2         0.001          True       0.162472
# 257  34HighDensity     100      2         0.001         False       0.153437
# 258  34HighDensity     100      2        0.0001          True       0.210474
# 259  34HighDensity     100      2        0.0001         False       0.196851
# 260  34HighDensity     100      3         0.001          True       0.168211
# 261  34HighDensity     100      3         0.001         False       0.148489
# 262  34HighDensity     100      3        0.0001          True       0.213848
# 263  34HighDensity     100      3        0.0001         False       0.194532
# 264  34HighDensity     101      1         0.001          True       0.171412
# 265  34HighDensity     101      1         0.001         False      0.0963885
# 266  34HighDensity     101      1        0.0001          True       0.174279
# 267  34HighDensity     101      1        0.0001         False       0.157001
# 268  34HighDensity     101      2         0.001          True       0.111141
# 269  34HighDensity     101      2         0.001         False       0.230856
# 270  34HighDensity     101      2        0.0001          True       0.214912
# 271  34HighDensity     101      2        0.0001         False       0.169574
# 272  34HighDensity     101      3         0.001          True       0.245909
# 273  34HighDensity     101      3         0.001         False       0.221171
# 274  34HighDensity     101      3        0.0001          True       0.211635
# 275  34HighDensity     101      3        0.0001         False       0.199732
# 276  34HighDensity     102      1         0.001          True      0.0503158
# 277  34HighDensity     102      1         0.001         False        0.05598
# 278  34HighDensity     102      1        0.0001          True      0.0490512
# 279  34HighDensity     102      1        0.0001         False      0.0433097
# 280  34HighDensity     102      2         0.001          True      0.0504664
# 281  34HighDensity     102      2         0.001         False      0.0538213
# 282  34HighDensity     102      2        0.0001          True      0.0510426
# 283  34HighDensity     102      2        0.0001         False      0.0502264
# 284  34HighDensity     102      3         0.001          True      0.0505236
# 285  34HighDensity     102      3         0.001         False      0.0570506
# 286  34HighDensity     102      3        0.0001          True      0.0580507
# 287  34HighDensity     102      3        0.0001         False      0.0554667
# 288  34HighDensity     103      1         0.001          True        0.13421
# 289  34HighDensity     103      1         0.001         False      0.0818932
# 290  34HighDensity     103      1        0.0001          True       0.309858
# 291  34HighDensity     103      1        0.0001         False       0.197635
# 292  34HighDensity     103      2         0.001          True       0.163862
# 293  34HighDensity     103      2         0.001         False       0.196426
# 294  34HighDensity     103      2        0.0001          True       0.203645
# 295  34HighDensity     103      2        0.0001         False       0.207507
# 296  34HighDensity     103      3         0.001          True       0.149589
# 297  34HighDensity     103      3         0.001         False       0.227705
# 298  34HighDensity     103      3        0.0001          True       0.162274
# 299  34HighDensity     103      3        0.0001         False       0.208059
# 300  34HighDensity     104      1         0.001          True      0.0718934
# 301  34HighDensity     104      1         0.001         False      0.0706398
# 302  34HighDensity     104      1        0.0001          True            inf
# 303  34HighDensity     104      1        0.0001         False            inf
# 304  34HighDensity     104      2         0.001          True       0.064747
# 305  34HighDensity     104      2         0.001         False      0.0668811
# 306  34HighDensity     104      2        0.0001          True            inf
# 307  34HighDensity     104      2        0.0001         False            inf
# 308  34HighDensity     104      3         0.001          True      0.0627506
# 309  34HighDensity     104      3         0.001         False      0.0632779
# 310  34HighDensity     104      3        0.0001          True            inf
# 311  34HighDensity     104      3        0.0001         False            inf
# 312  34HighDensity     105      1         0.001          True       0.213713
# 313  34HighDensity     105      1         0.001         False       0.068316
# 314  34HighDensity     105      1        0.0001          True       0.268471
# 315  34HighDensity     105      1        0.0001         False       0.225891
# 316  34HighDensity     105      2         0.001          True       0.204895
# 317  34HighDensity     105      2         0.001         False      0.0940739
# 318  34HighDensity     105      2        0.0001          True       0.270039
# 319  34HighDensity     105      2        0.0001         False       0.259392
# 320  34HighDensity     105      3         0.001          True       0.207317
# 321  34HighDensity     105      3         0.001         False       0.180709
# 322  34HighDensity     105      3        0.0001          True       0.279915
# 323  34HighDensity     105      3        0.0001         False       0.311327
# 324   34Expanded15      96      1         0.001          True       0.252293
# 325   34Expanded15      96      1         0.001         False        0.27137
# 326   34Expanded15      96      1        0.0001          True       0.268014
# 327   34Expanded15      96      1        0.0001         False       0.292714
# 328   34Expanded15      96      2         0.001          True       0.240725
# 329   34Expanded15      96      2         0.001         False       0.217978
# 330   34Expanded15      96      2        0.0001          True       0.282583
# 331   34Expanded15      96      2        0.0001         False       0.286992
# 332   34Expanded15      96      3         0.001          True       0.232426
# 333   34Expanded15      96      3         0.001         False       0.208247
# 334   34Expanded15      96      3        0.0001          True       0.274548
# 335   34Expanded15      96      3        0.0001         False       0.288295
# 336   34Expanded15      97      1         0.001          True        0.40818
# 337   34Expanded15      97      1         0.001         False       0.412243
# 338   34Expanded15      97      1        0.0001          True       0.363832
# 339   34Expanded15      97      1        0.0001         False       0.394912
# 340   34Expanded15      97      2         0.001          True       0.415342
# 341   34Expanded15      97      2         0.001         False       0.449773
# 342   34Expanded15      97      2        0.0001          True       0.348965
# 343   34Expanded15      97      2        0.0001         False       0.361845
# 344   34Expanded15      97      3         0.001          True       0.441316
# 345   34Expanded15      97      3         0.001         False        0.43796
# 346   34Expanded15      97      3        0.0001          True       0.336834
# 347   34Expanded15      97      3        0.0001         False       0.344258
# 348   34Expanded15      99      1         0.001          True       0.176669
# 349   34Expanded15      99      1         0.001         False        0.17954
# 350   34Expanded15      99      1        0.0001          True       0.181295
# 351   34Expanded15      99      1        0.0001         False        0.18774
# 352   34Expanded15      99      2         0.001          True       0.195224
# 353   34Expanded15      99      2         0.001         False       0.200925
# 354   34Expanded15      99      2        0.0001          True       0.190711
# 355   34Expanded15      99      2        0.0001         False       0.176903
# 356   34Expanded15      99      3         0.001          True       0.260854
# 357   34Expanded15      99      3         0.001         False       0.209529
# 358   34Expanded15      99      3        0.0001          True       0.185824
# 359   34Expanded15      99      3        0.0001         False       0.185577
# 360   34Expanded15     100      1         0.001          True            inf
# 361   34Expanded15     100      1         0.001         False            inf
# 362   34Expanded15     100      1        0.0001          True       0.339527
# 423   34Expanded15     105      1        0.0001         False       0.169503
# 424   34Expanded15     105      2         0.001          True       0.287948
# 425   34Expanded15     105      2         0.001         False       0.259888
# 426   34Expanded15     105      2        0.0001          True       0.450173
# 427   34Expanded15     105      2        0.0001         False       0.222575
# 428   34Expanded15     105      3         0.001          True       0.401997
# 429   34Expanded15     105      3         0.001         False        0.25941
# 430   34Expanded15     105      3        0.0001          True       0.296121
# 431   34Expanded15     105      3        0.0001         False       0.245461
#
#     norms_pms_lst
# 0        0.149087
# 1        0.149087
# 2        0.149087
# 3        0.149087
# 4        0.149087
# 5        0.149087
# 6        0.149087
# 7        0.149087
# 8        0.149087
# 9        0.149087
# 10       0.149087
# 11       0.149087
# 12      0.0945608
# 13      0.0945608
# 14      0.0945608
# 15      0.0945608
# 16      0.0945608
# 17      0.0945608
# 18      0.0945608
# 19      0.0945608
# 20      0.0945608
# 21      0.0945608
# 22      0.0945608
# 23      0.0945608
# 24      0.0682947
# 25      0.0682947
# 26      0.0682947
# 27      0.0682947
# 28      0.0682947
# 29      0.0682947
# 30      0.0682947
# 31      0.0682947
# 32      0.0682947
# 33      0.0682947
# 34      0.0682947
# 35      0.0682947
# 36       0.106988
# 37       0.106988
# 38       0.106988
# 39       0.106988
# 40       0.106988
# 41       0.106988
# 42       0.106988
# 43       0.106988
# 44       0.106988
# 45       0.106988
# 46       0.106988
# 47       0.106988
# 48      0.0537379
# 49      0.0537379
# 50      0.0537379
# 51      0.0537379
# 52      0.0537379
# 53      0.0537379
# 54      0.0537379
# 55      0.0537379
# 56      0.0537379
# 57      0.0537379
# 58      0.0537379
# 59      0.0537379
# 60      0.0537379
# 61      0.0537379
# 62      0.0537379
# 63      0.0537379
# 64      0.0537379
# 65      0.0537379
# 66      0.0537379
# 67      0.0537379
# 68      0.0537379
# 69      0.0537379
# 70      0.0537379
# 71      0.0537379
# 72      0.0387652
# 73      0.0387652
# 74      0.0387652
# 75      0.0387652
# 76      0.0387652
# 77      0.0387652
# 78      0.0387652
# 79      0.0387652
# 80      0.0387652
# 81      0.0387652
# 82      0.0387652
# 83      0.0387652
# 84      0.0387652
# 85      0.0387652
# 86      0.0481233
# 87      0.0481233
# 88      0.0481233
# 89      0.0481233
# 90      0.0481233
# 91      0.0481233
# 92      0.0481233
# 93      0.0481233
# 94      0.0481233
# 95      0.0481233
# 96      0.0268056
# 97      0.0268056
# 98      0.0268056
# 99      0.0268056
# 100     0.0268056
# 101     0.0268056
# 102     0.0268056
# 103     0.0268056
# 104     0.0268056
# 105     0.0268056
# 106     0.0268056
# 107     0.0268056
# 108      0.270229
# 109      0.270229
# 110      0.270229
# 111      0.270229
# 112      0.270229
# 113      0.270229
# 114      0.270229
# 115      0.270229
# 116      0.270229
# 117      0.270229
# 118      0.270229
# 119      0.270229
# 120     0.0641055
# 121     0.0641055
# 122     0.0641055
# 123     0.0641055
# 124     0.0641055
# 125     0.0641055
# 126     0.0641055
# 127     0.0641055
# 128     0.0641055
# 129     0.0641055
# 130     0.0641055
# 131     0.0641055
# 132     0.0746618
# 133     0.0746618
# 134     0.0746618
# 135     0.0746618
# 136     0.0746618
# 137     0.0746618
# 138     0.0746618
# 139     0.0746618
# 140     0.0746618
# 141     0.0746618
# 142     0.0746618
# 143     0.0746618
# 144     0.0978145
# 145     0.0978145
# 146     0.0978145
# 147     0.0978145
# 148     0.0978145
# 149     0.0978145
# 150     0.0978145
# 151     0.0978145
# 152     0.0978145
# 153     0.0978145
# 154     0.0978145
# 155     0.0978145
# 156     0.0344664
# 157     0.0344664
# 158     0.0344664
# 159     0.0344664
# 160     0.0344664
# 161     0.0344664
# 162     0.0344664
# 163     0.0344664
# 164     0.0344664
# 165     0.0344664
# 166     0.0344664
# 167     0.0344664
# 168     0.0693927
# 169     0.0693927
# 170     0.0693927
# 171     0.0693927
# 172     0.0693927
# 173     0.0693927
# 174     0.0693927
# 175     0.0693927
# 176     0.0693927
# 177     0.0693927
# 178     0.0693927
# 179     0.0693927
# 180     0.0314516
# 181     0.0314516
# 182     0.0314516
# 183     0.0314516
# 184     0.0314516
# 185     0.0314516
# 186     0.0314516
# 187     0.0314516
# 188     0.0314516
# 189     0.0314516
# 190     0.0314516
# 191     0.0314516
# 192     0.0642028
# 193     0.0642028
# 194     0.0642028
# 195     0.0642028
# 196     0.0642028
# 197     0.0642028
# 198     0.0642028
# 199     0.0642028
# 200     0.0642028
# 201     0.0642028
# 202     0.0642028
# 203     0.0642028
# 204     0.0511482
# 205     0.0511482
# 206     0.0511482
# 207     0.0511482
# 208     0.0511482
# 209     0.0511482
# 210     0.0511482
# 211     0.0511482
# 212     0.0511482
# 213     0.0511482
# 214     0.0511482
# 215     0.0511482
# 216      0.287902
# 217      0.287902
# 218      0.287902
# 219      0.287902
# 220      0.287902
# 221      0.287902
# 222      0.287902
# 223      0.287902
# 224      0.287902
# 225      0.287902
# 226      0.287902
# 227      0.287902
# 228     0.0551057
# 229     0.0551057
# 230     0.0551057
# 231     0.0551057
# 232     0.0551057
# 233     0.0551057
# 234     0.0551057
# 235     0.0551057
# 236     0.0551057
# 237     0.0551057
# 238     0.0551057
# 239     0.0551057
# 240     0.0724206
# 241     0.0724206
# 242     0.0724206
# 243     0.0724206
# 244     0.0724206
# 245     0.0724206
# 246     0.0724206
# 247     0.0724206
# 248     0.0724206
# 249     0.0724206
# 250     0.0724206
# 251     0.0724206
# 252     0.0924451
# 253     0.0924451
# 254     0.0924451
# 255     0.0924451
# 256     0.0924451
# 257     0.0924451
# 258     0.0924451
# 259     0.0924451
# 260     0.0924451
# 261     0.0924451
# 262     0.0924451
# 263     0.0924451
# 264     0.0442995
# 265     0.0442995
# 266     0.0442995
# 267     0.0442995
# 268     0.0442995
# 269     0.0442995
# 270     0.0442995
# 271     0.0442995
# 272     0.0442995
# 273     0.0442995
# 274     0.0442995
# 275     0.0442995
# 276     0.0678956
# 277     0.0678956
# 278     0.0678956
# 279     0.0678956
# 280     0.0678956
# 281     0.0678956
# 282     0.0678956
# 283     0.0678956
# 284     0.0678956
# 285     0.0678956
# 286     0.0678956
# 287     0.0678956
# 288     0.0369699
# 289     0.0369699
# 290     0.0369699
# 291     0.0369699
# 292     0.0369699
# 293     0.0369699
# 294     0.0369699
# 295     0.0369699
# 296     0.0369699
# 297     0.0369699
# 298     0.0369699
# 299     0.0369699
# 300     0.0558689
# 301     0.0558689
# 302     0.0558689
# 303     0.0558689
# 304     0.0558689
# 305     0.0558689
# 306     0.0558689
# 307     0.0558689
# 308     0.0558689
# 309     0.0558689
# 310     0.0558689
# 311     0.0558689
# 312     0.0456509
# 313     0.0456509
# 314     0.0456509
# 315     0.0456509
# 316     0.0456509
# 317     0.0456509
# 318     0.0456509
# 319     0.0456509
# 320     0.0456509
# 321     0.0456509
# 322     0.0456509
# 323     0.0456509
# 324     0.0752566
# 325     0.0752566
# 326     0.0752566
# 327     0.0752566
# 328     0.0752566
# 329     0.0752566
# 330     0.0752566
# 331     0.0752566
# 332     0.0752566
# 333     0.0752566
# 334     0.0752566
# 335     0.0752566
# 336     0.0948863
# 337     0.0948863
# 338     0.0948863
# 339     0.0948863
# 340     0.0948863
# 341     0.0948863
# 342     0.0948863
# 343     0.0948863
# 344     0.0948863
# 345     0.0948863
# 346     0.0948863
# 347     0.0948863
# 348     0.0927475
# 349     0.0927475
# 350     0.0927475
# 351     0.0927475
# 352     0.0927475
# 353     0.0927475
# 354     0.0927475
# 355     0.0927475
# 356     0.0927475
# 357     0.0927475
# 358     0.0927475
# 359     0.0927475
# 360     0.0927475
# 361     0.0927475
# 362     0.0919989
# 363     0.0919989
# 364     0.0919989
# 365     0.0919989
# 366     0.0919989
# 367     0.0919989
# 368     0.0919989
# 369     0.0919989
# 370     0.0919989
# 371     0.0919989
# 372     0.0668265
# 373     0.0668265
# 374     0.0668265
# 375     0.0668265
# 376     0.0668265
# 377     0.0668265
# 378     0.0668265
# 379     0.0668265
# 380     0.0668265
# 381     0.0668265
# 382     0.0668265
# 383     0.0668265
# 384      0.057278
# 385      0.057278
# 386      0.057278
# 387      0.057278
# 388      0.057278
# 389      0.057278
# 390      0.057278
# 391      0.057278
# 392      0.057278
# 393      0.057278
# 394      0.057278
# 395      0.057278
# 396      0.057278
# 397      0.057278
# 398      0.121239
# 399      0.121239
# 400      0.121239
# 401      0.121239
# 402      0.121239
# 403      0.121239
# 404      0.121239
# 405      0.121239
# 406      0.121239
# 407      0.121239
# 408     0.0519414
# 409     0.0519414
# 410     0.0519414
# 411     0.0519414
# 412     0.0519414
# 413     0.0519414
# 414     0.0519414
# 415     0.0519414
# 416     0.0519414
# 417     0.0519414
# 418     0.0519414
# 419     0.0519414
# 420     0.0448647
# 421     0.0448647
# 422     0.0448647
# 423     0.0448647
# 424     0.0448647
# 425     0.0448647
# 426     0.0448647
# 427     0.0448647
# 428     0.0448647
# 429     0.0448647
# 430     0.0448647
# 431     0.0448647

# %%
norms_type = norms.copy()


norms_type['gan_version'] =  norms_type['gan_version'].map({'34Orig': 'A',
                               '34HighDensity': 'B',
                               '34Expanded15': 'C',
                               '15ConstSpac': 'D'
                              })

norms_type['inferred_stud'] = norms_type['inferred_stud'].map({True: 'I', False: 'S'})
norms_type['learning_rate'] = norms_type['learning_rate'].astype(str)


# norms_type_tmp = norms_type[['gan_version', 'kernel', 'learning_rate', 'inferred_stud']].astype(str)
# norms_type['combo_name'] = norms_type_tmp['gan_version'] + '_' + norms_type_tmp['kernel'] + '_' + norms_type_tmp['learning_rate'] + '_' + norms_type_tmp['inferred_stud']
# norms_type['norms_pms_lst'] = norms_type['norms_pms_lst'].astype(float)

# %%
# norms_type['norms_pms_lst'].dtype

# %%
norms_type['norms_pms_lst']
# Out:
# 0       0.149087
# 1       0.149087
# 2       0.149087
# 3       0.149087
# 4       0.149087
#          ...
# 427    0.0448647
# 428    0.0448647
# 429    0.0448647
# 430    0.0448647
# 431    0.0448647
# Name: norms_pms_lst, Length: 432, dtype: object

# %%
# norms_type_us = norms_type[['bot_num', 'combo_name', 'norms_fake_lst']].set_index(['bot_num', 'combo_name']).unstack().copy()

final_setup_long = norms_type[['bot_num', 'gan_version', 'kernel', 'learning_rate', 'inferred_stud', 'norms_fake_lst', 'norms_pms_lst']].set_index(['gan_version', 'learning_rate', 'inferred_stud', 'kernel', 'bot_num']).stack().sort_index()
norms_type_us = final_setup_long.unstack(-2).unstack(-1).copy()

# norms_type_us['norms_pms_lst'] = norms_type.groupby(['bot_num'])['norms_pms_lst'].mean()
# norms_type_us['norms_pms_lst'] = norms_type.groupby(['gan_version', 'kernel', 'learning_rate', 'inferred_stud'])['norms_pms_lst'].mean()

norms_type_us
# Out:
# bot_num                                                   96                 \
#                                                norms_fake_lst norms_pms_lst
# gan_version learning_rate inferred_stud kernel
# A           0.0001        I             1                 inf      0.270229
#                                         2                 inf      0.270229
#                                         3                 inf      0.270229
#                           S             1                 inf      0.270229
#                                         2                 inf      0.270229
#                                         3                 inf      0.270229
#             0.001         I             1            0.179123      0.270229
#                                         2            0.167482      0.270229
#                                         3            0.171978      0.270229
#                           S             1            0.210998      0.270229
#                                         2            0.202969      0.270229
#                                         3            0.180504      0.270229
# B           0.0001        I             1            0.213098      0.287902
#                                         2            0.216343      0.287902
#                                         3            0.243543      0.287902
#                           S             1            0.268339      0.287902
#                                         2            0.233095      0.287902
#                                         3            0.235779      0.287902
#             0.001         I             1            0.194591      0.287902
#                                         2            0.194316      0.287902
#                                         3            0.196392      0.287902
#                           S             1            0.232593      0.287902
#                                         2            0.194962      0.287902
#                                         3            0.197611      0.287902
# C           0.0001        I             1            0.268014     0.0752566
#                                         2            0.282583     0.0752566
#                                         3            0.274548     0.0752566
#                           S             1            0.292714     0.0752566
#                                         2            0.286992     0.0752566
#                                         3            0.288295     0.0752566
#             0.001         I             1            0.252293     0.0752566
#                                         2            0.240725     0.0752566
#                                         3            0.232426     0.0752566
#                           S             1             0.27137     0.0752566
#                                         2            0.217978     0.0752566
#                                         3            0.208247     0.0752566
# D           0.0001        I             1            0.192778      0.149087
#                                         2            0.194176      0.149087
#                                         3              0.1815      0.149087
#                           S             1            0.188855      0.149087
#                                         2            0.190539      0.149087
#                                         3            0.178094      0.149087
#             0.001         I             1            0.132538      0.149087
#                                         2            0.127754      0.149087
#                                         3            0.140808      0.149087
#                           S             1            0.128172      0.149087
#                                         2            0.136348      0.149087
#                                         3             0.14299      0.149087
#
#             0.001         I             1                 inf     0.0387652
#                                         2                 inf     0.0481233
#                                         3                 inf     0.0481233
#                           S             1                 inf     0.0387652
#                                         2                 inf     0.0481233
#                                         3                 inf     0.0481233
#
# bot_num                                                   105
#                                                norms_fake_lst norms_pms_lst
# gan_version learning_rate inferred_stud kernel
# A           0.0001        I             1                 inf     0.0511482
#                                         2                 inf     0.0511482
#                                         3                 inf     0.0511482
#                           S             1                 inf     0.0511482
#                                         2                 inf     0.0511482
#                                         3                 inf     0.0511482
#             0.001         I             1            0.158948     0.0511482
#                                         2            0.115619     0.0511482
#                                         3           0.0782957     0.0511482
#                           S             1            0.132278     0.0511482
#                                         2           0.0946978     0.0511482
#                                         3           0.0790855     0.0511482
# B           0.0001        I             1            0.268471     0.0456509
#                                         2            0.270039     0.0456509
#                                         3            0.279915     0.0456509
#                           S             1            0.225891     0.0456509
#                                         2            0.259392     0.0456509
#                                         3            0.311327     0.0456509
#             0.001         I             1            0.213713     0.0456509
#                                         2            0.204895     0.0456509
#                                         3            0.207317     0.0456509
#                           S             1            0.068316     0.0456509
#                                         2           0.0940739     0.0456509
#                                         3            0.180709     0.0456509
# C           0.0001        I             1            0.276534     0.0448647
#                                         2            0.450173     0.0448647
#                                         3            0.296121     0.0448647
#                           S             1            0.169503     0.0448647
#                                         2            0.222575     0.0448647
#                                         3            0.245461     0.0448647
#             0.001         I             1            0.269586     0.0448647
#                                         2            0.287948     0.0448647
#                                         3            0.401997     0.0448647
#                           S             1            0.239187     0.0448647
#                                         2            0.259888     0.0448647
#                                         3             0.25941     0.0448647
# D           0.0001        I             1            0.414186     0.0268056
#                                         2            0.272396     0.0268056
#                                         3            0.269269     0.0268056
#                           S             1            0.245181     0.0268056
#                                         2            0.354559     0.0268056
#                                         3            0.342805     0.0268056
#             0.001         I             1            0.133926     0.0268056
#                                         2           0.0772601     0.0268056
#                                         3           0.0612298     0.0268056
#                           S             1            0.157885     0.0268056
#                                         2            0.103741     0.0268056
#                                         3           0.0775849     0.0268056

# %%
PMS_plot_setup = final_setup_long.unstack()['norms_pms_lst'].astype(float)
PMS_plot = PMS_plot_setup.unstack().groupby(['gan_version']).mean()
ax = PMS_plot.plot.bar(figsize=(8,7),
                       title='Surface L2 vs. Case by Example — Pure PMS',
                       xlabel='Case',
                       ylabel='Surface L2 (SL2)'
                      )

for tick in ax.get_xticklabels():
    tick.set_rotation(0)
plt.ylim((0,.45))
plt.grid()
plt.show()
ax.get_figure().savefig('./final_plots/ppms-01.png', dpi=200)

ax = PMS_plot.plot.bar(figsize=(8,4),
                       title='Surface L2 vs. Case by Example — Pure PMS',
                       xlabel='Case',
                       ylabel='Surface L2 (SL2)'
                      )

for tick in ax.get_xticklabels():
    tick.set_rotation(0)
plt.ylim((0,.45))
plt.grid()
plt.show()
ax.get_figure().savefig('./final_plots/ppms-02.png', dpi=200)

# %%
# final_setup_long.unstack()['norms_fake_lst'].astype(float).unstack()

# %%
GAN_LR_plot_setup = final_setup_long.unstack()['norms_fake_lst'].astype(float).reset_index()
GAN_LR_plot_setup['is_rel'] = GAN_LR_plot_setup.reset_index()['kernel'] == 1
GAN_LR_plot_setup = GAN_LR_plot_setup[GAN_LR_plot_setup['is_rel']].drop('is_rel', axis=1).set_index(['gan_version','learning_rate','inferred_stud','kernel','bot_num'])
GAN_LR_plot_setup = GAN_LR_plot_setup['norms_fake_lst'].unstack()
GAN_LR_plot_setup = GAN_LR_plot_setup.groupby(['gan_version', 'learning_rate']).min()

ax = GAN_LR_plot_setup.plot.bar(figsize=(8,7),
                       title='Surface L2 vs. Case / Learning Rate by Example — GAN PMS',
                       xlabel='Case / GAN Learning Rate',
                       ylabel='Surface L2 (SL2)'
                      )
ax.legend(loc='upper left')
plt.ylim((0,.45))
plt.grid()
for tick in ax.get_xticklabels():
    tick.set_rotation(0)
plt.show()
ax.get_figure().savefig('./final_plots/lr-01.png', dpi=200)

ax = GAN_LR_plot_setup.plot.bar(figsize=(8,4),
                       title='Surface L2 vs. Case / Learning Rate by Example — GAN PMS',
                       xlabel='Case / GAN Learning Rate',
                       ylabel='Surface L2 (SL2)'
                      )

for tick in ax.get_xticklabels():
    tick.set_rotation(0)
ax.legend(loc='upper left')
plt.ylim((0,.45))
plt.grid()
plt.show()
ax.get_figure().savefig('./final_plots/lr-02.png', dpi=200)



GAN_LR_plot_setup#.reset_index()
# Out:
# bot_num                         96        97        99        100       101  \
# gan_version learning_rate
# A           0.0001              inf       inf       inf       inf       inf
#             0.001          0.179123  0.200086  0.211002  0.207548  0.119893
# B           0.0001         0.213098  0.161911  0.141630  0.154846  0.157001
#             0.001          0.194591  0.390914  0.188863  0.130977  0.096389
# C           0.0001         0.268014  0.363832  0.181295  0.325492  0.044996
#             0.001          0.252293  0.408180  0.176669       inf  0.089385
# D           0.0001         0.188855  0.399296  0.353085  0.169636  0.242002
#             0.001          0.128172  0.345868  0.151131  0.183920  0.251132
#
# bot_num                         102       103       104       105
# gan_version learning_rate
# A           0.0001              inf       inf       inf       inf
#             0.001          0.067998  0.132622  0.089627  0.132278
# B           0.0001         0.043310  0.197635       inf  0.225891
#             0.001          0.050316  0.081893  0.070640  0.068316
# C           0.0001         0.073289  0.189180  0.134756  0.169503
#             0.001          0.119461       inf  0.219477  0.239187
# D           0.0001              inf  0.244520  0.354789  0.245181
#             0.001               inf  0.058378       inf  0.133926

# %%
GAN_IS_plot_setup = final_setup_long.unstack()['norms_fake_lst'].astype(float).reset_index()
GAN_IS_plot_setup['is_rel'] = GAN_IS_plot_setup.reset_index()['kernel'] == 1
GAN_IS_plot_setup = GAN_IS_plot_setup[GAN_IS_plot_setup['is_rel']].drop('is_rel', axis=1).set_index(['gan_version','learning_rate','inferred_stud','kernel','bot_num'])
GAN_IS_plot_setup = GAN_IS_plot_setup['norms_fake_lst'].unstack()
GAN_IS_plot_setup = GAN_IS_plot_setup.groupby(['gan_version', 'inferred_stud']).min()
ax = GAN_IS_plot_setup.plot.bar(figsize=(8,7),
                       title='Surface L2 vs. Case / Studio Light Method by Example — GAN PMS',
                       xlabel='Case / Studio Ground Truth (S) or Inferred (I)',
                       ylabel='Surface L2 (SL2)'
                      )
# ax.legend(loc='upper left')
plt.legend(loc=(1.02, 0.635))
plt.ylim((0,.45))
plt.grid()

for tick in ax.get_xticklabels():
    tick.set_rotation(0)
ax.get_figure().savefig('./final_plots/is-01.png', dpi=200, bbox_inches='tight')


ax = GAN_IS_plot_setup.plot.bar(figsize=(8,4),
                       title='Surface L2 vs. Case / Studio Light Method by Example — GAN PMS',
                       xlabel='Case / Studio Ground Truth (S) or Inferred (I)',
                       ylabel='Surface L2 (SL2)'
                      )
plt.legend(loc=(1.02, 0.36))
# ax.legend(loc='upper left')
plt.ylim((0,.45))
plt.grid()

for tick in ax.get_xticklabels():
    tick.set_rotation(0)
ax.get_figure().savefig('./final_plots/is-02.png', dpi=200, bbox_inches='tight')


GAN_IS_plot_setup#.reset_index()
# Out:
# bot_num                         96        97        99        100       101  \
# gan_version inferred_stud
# A           I              0.179123  0.200086  0.291585  0.207548  0.119893
#             S              0.210998  0.248757  0.211002  0.207988  0.128606
# B           I              0.194591  0.424721  0.141630  0.162512  0.171412
#             S              0.232593  0.161911  0.186381  0.130977  0.096389
# C           I              0.252293  0.363832  0.176669  0.339527  0.045372
#             S              0.271370  0.394912  0.179540  0.325492  0.044996
# D           I              0.132538  0.347536  0.151131  0.183920  0.242002
#             S              0.128172  0.345868  0.197779  0.169636  0.246285
#
# bot_num                         102       103       104       105
# gan_version inferred_stud
# A           I              0.425270  0.154428  0.090442  0.158948
#             S              0.067998  0.132622  0.089627  0.132278
# B           I              0.049051  0.134210  0.071893  0.213713
#             S              0.043310  0.081893  0.070640  0.068316
# C           I              0.092071  0.296668  0.160337  0.269586
#             S              0.073289  0.189180  0.134756  0.169503
# D           I                   inf  0.078763  0.354789  0.133926
#             S                   inf  0.058378  0.382818  0.157885

# %%
GAN_IS_plot_setup
# Out:
# bot_num                         96        97        99        100       101  \
# gan_version inferred_stud
# A           I              0.179123  0.200086  0.291585  0.207548  0.119893
#             S              0.210998  0.248757  0.211002  0.207988  0.128606
# B           I              0.194591  0.424721  0.141630  0.162512  0.171412
#             S              0.232593  0.161911  0.186381  0.130977  0.096389
# C           I              0.252293  0.363832  0.176669  0.339527  0.045372
#             S              0.271370  0.394912  0.179540  0.325492  0.044996
# D           I              0.132538  0.347536  0.151131  0.183920  0.242002
#             S              0.128172  0.345868  0.197779  0.169636  0.246285
#
# bot_num                         102       103       104       105
# gan_version inferred_stud
# A           I              0.425270  0.154428  0.090442  0.158948
#             S              0.067998  0.132622  0.089627  0.132278
# B           I              0.049051  0.134210  0.071893  0.213713
#             S              0.043310  0.081893  0.070640  0.068316
# C           I              0.092071  0.296668  0.160337  0.269586
#             S              0.073289  0.189180  0.134756  0.169503
# D           I                   inf  0.078763  0.354789  0.133926
#             S                   inf  0.058378  0.382818  0.157885

# %%
GAN_IS_plot_setup = final_setup_long.unstack()['norms_fake_lst'].astype(float).reset_index()
GAN_IS_plot_setup['is_rel'] = (GAN_IS_plot_setup.reset_index()['gan_version'] == 'A')&(GAN_IS_plot_setup.reset_index()['learning_rate'] == '0.001')&(GAN_IS_plot_setup.reset_index()['inferred_stud'] == 'S')
GAN_IS_plot_setup = GAN_IS_plot_setup[GAN_IS_plot_setup['is_rel']].drop('is_rel', axis=1).set_index(['gan_version','learning_rate','inferred_stud','kernel','bot_num'])
GAN_IS_plot_setup = GAN_IS_plot_setup['norms_fake_lst'].unstack()
GAN_IS_plot_setup = GAN_IS_plot_setup.groupby(['gan_version', 'learning_rate', 'inferred_stud', 'kernel']).min()
ax = GAN_IS_plot_setup.plot.bar(figsize=(8,7),
                       title='SL2 vs. Case A Average Pooling Kernel Size by Example — GAN PMS',
                       xlabel='Case A Average Pooling Kernel Size (1x1, 2x2, or 3x3)',
                       ylabel='Surface L2 (SL2)'
                      )
ax.legend(loc='upper right')
plt.ylim((0,.45))
plt.grid()

for tick in ax.get_xticklabels():
    tick.set_rotation(0) 
ax.get_figure().savefig('./final_plots/avg-01.png', dpi=200)


ax = GAN_IS_plot_setup.plot.bar(figsize=(8,4),
                       title='SL2 vs. Case A Average Pooling Kernel Size by Example — GAN PMS',
                       xlabel='Case A Average Pooling Kernel Size (1x1, 2x2, or 3x3)',
                       ylabel='Surface L2 (SL2)'
                      )
ax.legend(loc='upper right')
plt.ylim((0,.45))
plt.grid()

for tick in ax.get_xticklabels():
    tick.set_rotation(0)
ax.get_figure().savefig('./final_plots/avg-02.png', dpi=200)


GAN_IS_plot_setup#.reset_index()
# Out:
# bot_num                                              96        97        99   \
# gan_version learning_rate inferred_stud kernel
# A           0.001         S             1       0.210998  0.248757  0.211002
#                                         2       0.202969  0.221647  0.083774
#                                         3       0.180504  0.202820  0.154421
#
# bot_num                                              100       101       102  \
# gan_version learning_rate inferred_stud kernel
# A           0.001         S             1       0.207988  0.128606  0.067998
#                                         2       0.104435  0.231567  0.080069
#                                         3       0.250609  0.258297  0.056865
#
# bot_num                                              103       104       105
# gan_version learning_rate inferred_stud kernel
# A           0.001         S             1       0.132622  0.089627  0.132278
#                                         2       0.101055  0.112237  0.094698
#                                         3       0.151763  0.153217  0.079085

# %%
# GAN_LR_plot_setup.plot.bar?

# %%
# GAN_LR_plot_setup = final_setup_long.unstack()['norms_fake_lst'].astype(float).reset_index()
# GAN_LR_plot_setup['is_rel'] = GAN_LR_plot_setup.reset_index()['kernel'] == 1
# GAN_LR_plot_setup = GAN_LR_plot_setup[GAN_LR_plot_setup['is_rel']].drop('is_rel', axis=1).set_index(['gan_version','learning_rate','inferred_stud','kernel','bot_num'])
# GAN_LR_plot_setup = GAN_LR_plot_setup['norms_fake_lst'].unstack()
# GAN_LR_plot_setup = GAN_LR_plot_setup.groupby(['gan_version', 'inferred_stud', 'learning_rate']).min()
# ax = GAN_LR_plot_setup.plot.bar(figsize=(12,6))

# for tick in ax.get_xticklabels():
#     tick.set_rotation(60)

# plt.grid()
# GAN_LR_plot_setup#.reset_index()

# %%
# Full Table — In Appendix
# * PMS by different Lighting Conditions
# * No Averaging
# * Averaging for the Best Lighting


# * Pure PMS by LC
# * GAN-Method (4), Kernel Size 1, LR (2) — 8 Bars per Index
# * GAN-Method (4), Kernel Size 1, Inferred Studio (2) — 8 Bars per Index
# * Best GAN-Method / LR / IS — 3 Kernel Sizes per Index
